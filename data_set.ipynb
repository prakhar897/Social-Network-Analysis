# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.read_edgelist('ego-twitter/out.ego-twitter')

# %%
print(nx.info(G))
nx.draw_circular(G)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 85
# Number of edges: 84
# Average degree:   1.9765
# c:\users\prakhar gupta\appdata\local\programs\python\python37-32\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
